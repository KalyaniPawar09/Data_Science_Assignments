# %% [markdown]
# Chi square test

# %%
#2
import scipy.stats as stats
import numpy as np
satisfaction = np.array([[50, 70],  # Very satisfied
                     [80, 100],  # Satisfied
                     [60, 90],   # Neutral
                     [30, 50],   # Unsatisfied
                     [20, 50]])  # Very unsatisfied

# %%
chi2_stat,p_val,dof,expected=stats.chi2_contingency(satisfaction)
print("Chi-Square satistic (X2):",chi2_stat)
print("P-value:",p_val)
print("Degrees of freedom:",dof)
print("Expected frequencies:\n",expected)
# Out:
# Chi-Square satistic (X2): 5.638227513227513
# P-value: 0.22784371130697179
# Degrees of freedom: 4
# Expected frequencies:
#  [[ 48.  72.]
#  [ 72. 108.]
#  [ 60.  90.]
#  [ 32.  48.]
#  [ 28.  42.]]

# %%
#3
alpha = 0.05
critical_value = stats.chi2.ppf(1 - alpha, dof)
print("Critical Value:", critical_value)
# Out:
# Critical Value: 9.487729036781154

# %%
#4
if chi2_stat > critical_value:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

# Display the decision
print("Decision:", decision)
# Out:
# Decision: Fail to reject the null hypothesis

# %%
#1 as we fail to reject the null hypothesis,The state of hypothesis is null hypothesis

# %% [markdown]
# 22/08/2024 hypothesis testing

# %%
from scipy.stats import t
import math

# %%
samplemean = 3050  # Sample mean
theoreticalmean = 4000  # Theoretical mean
standarddev = 5 * 25  # given Standard deviation of the
samplesize = 25  # given Sample size
alpha = 0.05  #given Significance level

# %%
#2
test_statistic = (samplemean - theoreticalmean) / (standarddev / math.sqrt(samplesize))
print("test statistic value :",test_statistic)
# Out:
# test statistic value : -38.0

# %%
#3
dof=samplesize-1
print("degree of freedom :",dof)
critical_value=t.ppf(1-alpha,dof)
print("critical value :",critical_value)
# Out:
# degree of freedom : 24
# critical value : 1.7108820799094275

# %%
#4
if test_statistic < critical_value:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

print("Decision:", decision)
# Out:
# Decision: Reject the null hypothesis

# %%
#5
'''
There is strong evidence to support the restaurant owners'
claim that the weekly operating costs have increased beyond what
the theoretical cost model predicts. ​
'''
#1
'''
As the Mean weekly operating cost is gretaer than the theoretical cost model
the state is Alternate Hypothesis
'''
