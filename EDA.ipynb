# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
#1.1
df = pd.read_csv("/content/Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
print(df.head())
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
#1.2
missing_val = df.isnull().sum()
print(missing_val)
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df = df.dropna()
missing_val = df.isnull().sum()
print(missing_val)
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
#1.3
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.343598     0.003202     0.009963     0.004388     0.001892
# std      11.270154     0.004324     0.067870     0.003350     0.003348
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.000003     0.000175    46.996929     1.361006    10.353647
# std       0.000142     0.000840    18.847737     1.173164    21.282102
# ...

# %%
print(df.dtypes)
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
#1.4 DETECTING AND CLEANING OUTLIERS
sns.boxplot(df["LB"])
# Out:
# <Axes: ylabel='LB'>

# %%
sns.boxplot(df["AC"])
# Out:
# <Axes: ylabel='AC'>

# %%
sns.boxplot(df["FM"])
# Out:
# <Axes: ylabel='FM'>

# %%
sns.boxplot(df["UC"])
# Out:
# <Axes: ylabel='UC'>

# %%
sns.boxplot(df["DL"])
# Out:
# <Axes: ylabel='DL'>

# %%
sns.boxplot(df["DS"])
# Out:
# <Axes: ylabel='DS'>

# %%
sns.boxplot(df["DP"])
# Out:
# <Axes: ylabel='DP'>

# %%
sns.boxplot(df["ASTV"])
# Out:
# <Axes: ylabel='ASTV'>

# %%
sns.boxplot(df["MSTV"])
# Out:
# <Axes: ylabel='MSTV'>

# %%
sns.boxplot(df["ALTV"])
# Out:
# <Axes: ylabel='ALTV'>

# %%
sns.boxplot(df["MLTV"])
# Out:
# <Axes: ylabel='MLTV'>

# %%
sns.boxplot(df["Width"])
# Out:
# <Axes: ylabel='Width'>

# %%
sns.boxplot(df["Tendency"])
# Out:
# <Axes: ylabel='Tendency'>

# %%
sns.boxplot(df["NSP"])
# Out:
# <Axes: ylabel='NSP'>

# %%
q1 = np.percentile(df["LB"],25)
q3 = np.percentile(df["LB"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr

# %%
df[df["LB"]>ub]
# Out:
#          LB        AC        FM        UC        DL        DS   DP       ASTV  \
# 411   214.0  0.000000  0.000000  0.001595  0.001595  0.000000  0.0  71.000000
# 610   214.0  0.002469  0.002469  0.002469  0.000000  0.000004  0.0  35.000000
# 612   214.0  0.005181  0.012953  0.002591  0.000000  0.000000  0.0  39.442226
# 1103  214.0  0.006972  0.000000  0.002960  0.000000  0.000000  0.0  19.000000
# 1406  214.0  0.005068  0.000000  0.001689  0.000000  0.000000  0.0  46.000000
# 1504  214.0  0.006189  0.000000  0.006189  0.000000  0.000000  0.0  38.000000
#
#           MSTV  ALTV  MLTV  Width  Tendency     NSP
# 411   0.300000  17.0   5.8   15.0       0.0  2.0000
# 610   1.798149   0.0  24.7  118.0       1.0  1.0000
# 612   1.600000   0.0  10.0  136.0       0.0  0.9912
# 1103  2.300000   0.0  12.1   53.0       0.0  1.0000
# 1406  0.800000   0.0   8.6   67.0       1.0  1.0000
# 1504  1.000000   0.0   8.1   53.0       0.0  1.0000

# %%
df["LB"][df["LB"]>ub] = ub
df["LB"][df["LB"]<lb] = lb
# Out:
# <ipython-input-29-0df640d72f0a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LB"][df["LB"]>ub] = ub
# <ipython-input-29-0df640d72f0a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["LB"][df["LB"]<lb] = lb

# %%
sns.boxplot(df["LB"])
# Out:
# <Axes: ylabel='LB'>

# %%
q1 = np.percentile(df["AC"],25)
q3 = np.percentile(df["AC"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr

# %%
df[df["AC"]>ub]
# Out:
#          LB        AC        FM        UC        DL        DS   DP       ASTV  \
# 8     122.0  0.038567  0.000000  0.001517  0.000000  0.000000  0.0  84.000000
# 83    145.0  0.014706  0.008403  0.002101  0.000000  0.000000  0.0  43.000000
# 85    145.0  0.014230  0.025873  0.001294  0.000000  0.000000  0.0  40.000000
# 181   138.0  0.017241  0.000000  0.005305  0.000000  0.000000  0.0  35.000000
# 496   130.0  0.014178  0.091743  0.000938  0.000000  0.000000  0.0  32.000000
# 497   130.0  0.015552  0.083981  0.001555 -0.000026  0.000000  0.0  34.000000
# 498   130.0  0.015258  0.115023  0.000000  0.000000  0.000000  0.0  31.000000
# 500   131.0  0.014178  0.015013  0.000834  0.000000  0.000000  0.0  29.000000
# 501   131.0  0.014726  0.017403  0.001339  0.000000  0.000000  0.0  31.000000
# 526   142.0  0.015013  0.062552  0.001668  0.000834  0.000000  0.0  36.000000
# 529   142.0  0.019284  0.085399  0.000000  0.000000  0.000000  0.0  32.000000
# ...

# %%
df["AC"][df["AC"]>ub] = ub
df["AC"][df["AC"]<lb] = lb
# Out:
# <ipython-input-33-21e20ea0ca5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AC"][df["AC"]>ub] = ub
# <ipython-input-33-21e20ea0ca5a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AC"][df["AC"]<lb] = lb

# %%
sns.boxplot(df["AC"])
# Out:
# <Axes: ylabel='AC'>

# %%
q1 = np.percentile(df["FM"],25)
q3 = np.percentile(df["FM"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr

# %%
df[df["FM"]>ub]
# Out:
#          LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 12    131.0  0.005076  0.072335  0.007614  0.002538  0.0  0.000000  28.0
# 13    131.0  0.009077  0.222390  0.006051  0.001513  0.0  0.000000  28.0
# 14    130.0  0.005838  0.407840  0.004170  0.005004  0.0  0.000826  21.0
# 15    130.0  0.005571  0.380223  0.004178  0.004178  0.0  0.001393  19.0
# 16    130.0  0.006088  0.441400  0.004566  0.004566  0.0  0.000000  24.0
# ...     ...       ...       ...       ...       ...  ...       ...   ...
# 2083  130.0  0.000000  0.008861  0.007595  0.000000  0.0  0.000000  73.0
# 2099  133.0  0.000000  0.008653  0.004944  0.000000  0.0  0.000000  72.0
# 2100  133.0  0.000000  0.009840  0.004920  0.000000  0.0  0.000000  70.0
# 2101  133.0  0.000000  0.009357  0.008187  0.000000  0.0  0.000000  69.0
# 2121  140.0  0.000000  0.961268  0.007426  0.000000  0.0  0.000000  79.0
#
#         MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
df["FM"][df["FM"]>ub] = ub
df["FM"][df["FM"]<lb] = lb
# Out:
# <ipython-input-37-310c58a6e358>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FM"][df["FM"]>ub] = ub
# <ipython-input-37-310c58a6e358>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["FM"][df["FM"]<lb] = lb

# %%
sns.boxplot(df["FM"])
# Out:
# <Axes: ylabel='FM'>

# %%
q1 = np.percentile(df["UC"],25)
q3 = np.percentile(df["UC"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["UC"]>ub]
df["UC"][df["UC"]>ub] = ub
df["UC"][df["UC"]<lb] = lb
sns.boxplot(df["UC"])
# Out:
# <ipython-input-39-f3844f98d5ec>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["UC"][df["UC"]>ub] = ub
# <ipython-input-39-f3844f98d5ec>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["UC"][df["UC"]<lb] = lb
# <Axes: ylabel='UC'>

# %%
q1 = np.percentile(df["DL"],25)
q3 = np.percentile(df["DL"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["DL"]>ub]
df["DL"][df["DL"]>ub] = ub
df["DL"][df["DL"]<lb] = lb
sns.boxplot(df["DL"])
# Out:
# <ipython-input-40-03c2f5a7af08>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DL"][df["DL"]>ub] = ub
# <ipython-input-40-03c2f5a7af08>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DL"][df["DL"]<lb] = lb
# <Axes: ylabel='DL'>

# %%
q1 = np.percentile(df["DS"],25)
q3 = np.percentile(df["DS"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["DS"]>ub]
df["DS"][df["DS"]>ub] = ub
df["DS"][df["DS"]<lb] = lb
sns.boxplot(df["DS"])
# Out:
# <ipython-input-41-f1ba11193ee4>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DS"][df["DS"]>ub] = ub
# <ipython-input-41-f1ba11193ee4>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DS"][df["DS"]<lb] = lb
# <Axes: ylabel='DS'>

# %%
q1 = np.percentile(df["DP"],25)
q3 = np.percentile(df["DP"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["DP"]>ub]
df["DP"][df["DP"]>ub] = ub
df["DP"][df["DP"]<lb] = lb
sns.boxplot(df["DP"])
# Out:
# <ipython-input-42-0dbacbc4e89e>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DP"][df["DP"]>ub] = ub
# <ipython-input-42-0dbacbc4e89e>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["DP"][df["DP"]<lb] = lb
# <Axes: ylabel='DP'>

# %%
q1 = np.percentile(df["ASTV"],25)
q3 = np.percentile(df["ASTV"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["ASTV"]>ub]
df["ASTV"][df["ASTV"]>ub] = ub
df["ASTV"][df["ASTV"]<lb] = lb
sns.boxplot(df["ASTV"])
# Out:
# <ipython-input-43-361c2f4f9d7a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ASTV"][df["ASTV"]>ub] = ub
# <ipython-input-43-361c2f4f9d7a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ASTV"][df["ASTV"]<lb] = lb
# <Axes: ylabel='ASTV'>

# %%
q1 = np.percentile(df["MSTV"],25)
q3 = np.percentile(df["MSTV"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["MSTV"]>ub]
df["MSTV"][df["MSTV"]>ub] = ub
df["MSTV"][df["MSTV"]<lb] = lb
sns.boxplot(df["MSTV"])
# Out:
# <ipython-input-44-eb60662287a2>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MSTV"][df["MSTV"]>ub] = ub
# <ipython-input-44-eb60662287a2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MSTV"][df["MSTV"]<lb] = lb
# <Axes: ylabel='MSTV'>

# %%
q1 = np.percentile(df["ALTV"],25)
q3 = np.percentile(df["ALTV"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["ALTV"]>ub]
df["ALTV"][df["ALTV"]>ub] = ub
df["ALTV"][df["ALTV"]<lb] = lb
sns.boxplot(df["ALTV"])
# Out:
# <ipython-input-45-a3208e385a72>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ALTV"][df["ALTV"]>ub] = ub
# <ipython-input-45-a3208e385a72>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ALTV"][df["ALTV"]<lb] = lb
# <Axes: ylabel='ALTV'>

# %%
q1 = np.percentile(df["MLTV"],25)
q3 = np.percentile(df["MLTV"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["MLTV"]>ub]
df["MLTV"][df["MLTV"]>ub] = ub
df["MLTV"][df["MLTV"]<lb] = lb
sns.boxplot(df["MLTV"])
# Out:
# <ipython-input-46-851c1194b35d>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MLTV"][df["MLTV"]>ub] = ub
# <ipython-input-46-851c1194b35d>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["MLTV"][df["MLTV"]<lb] = lb
# <Axes: ylabel='MLTV'>

# %%
q1 = np.percentile(df["Width"],25)
q3 = np.percentile(df["Width"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["Width"]>ub]
df["Width"][df["Width"]>ub] = ub
df["Width"][df["Width"]<lb] = lb
sns.boxplot(df["Width"])
# Out:
# <ipython-input-47-ebfc37eac534>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Width"][df["Width"]>ub] = ub
# <ipython-input-47-ebfc37eac534>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Width"][df["Width"]<lb] = lb
# <Axes: ylabel='Width'>

# %%
q1 = np.percentile(df["Tendency"],25)
q3 = np.percentile(df["Tendency"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["Tendency"]>ub]
df["Tendency"][df["Tendency"]>ub] = ub
df["Tendency"][df["Tendency"]<lb] = lb
sns.boxplot(df["Tendency"])
# Out:
# <ipython-input-48-d1af890c2130>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Tendency"][df["Tendency"]>ub] = ub
# <ipython-input-48-d1af890c2130>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Tendency"][df["Tendency"]<lb] = lb
# <Axes: ylabel='Tendency'>

# %%
q1 = np.percentile(df["NSP"],25)
q3 = np.percentile(df["NSP"],75)

iqr = q3-q1

ub = q3+1.5*iqr
lb = q1-1.5*iqr
df[df["NSP"]>ub]
df["NSP"][df["NSP"]>ub] = ub
df["NSP"][df["NSP"]<lb] = lb
sns.boxplot(df["NSP"])
# Out:
# <ipython-input-49-34e61017a3e7>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NSP"][df["NSP"]>ub] = ub
# <ipython-input-49-34e61017a3e7>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NSP"][df["NSP"]<lb] = lb
# <Axes: ylabel='NSP'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2105 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2105 non-null   float64
#  2   FM        2105 non-null   float64
#  3   UC        2105 non-null   float64
#  4   DL        2105 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2105 non-null   float64
#  8   MSTV      2105 non-null   float64
#  9   ALTV      2105 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 246.7 KB

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.293227     0.003143     0.001561     0.004358     0.001768
# std       9.979659     0.003843     0.002473     0.003008     0.002672
# min     105.000000    -0.008475    -0.003831    -0.005209    -0.004934
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     161.000000     0.014124     0.006386     0.013583     0.008224
#
#            DS      DP         ASTV         MSTV         ALTV         MLTV  \
# count  2105.0  2105.0  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.0     0.0    46.982677     1.302006     6.727067     8.022202
# std       0.0     0.0    17.636431     0.779684    10.397529     5.094420
# ...

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.006386  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV  ALTV   MLTV  Width  Tendency  NSP
# ...

# %%
numerical_summary = df.describe()
print(numerical_summary)
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2105.000000  2105.000000  2105.000000  2105.000000
# mean    133.293227     0.003143     0.001561     0.004358     0.001768
# std       9.979659     0.003843     0.002473     0.003008     0.002672
# min     105.000000    -0.008475    -0.003831    -0.005209    -0.004934
# 25%     126.000000     0.000000     0.000000     0.001838     0.000000
# 50%     133.000000     0.001631     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002554     0.006536     0.003289
# max     161.000000     0.014124     0.006386     0.013583     0.008224
#
#            DS      DP         ASTV         MSTV         ALTV         MLTV  \
# count  2105.0  2105.0  2105.000000  2105.000000  2105.000000  2105.000000
# mean      0.0     0.0    46.982677     1.302006     6.727067     8.022202
# std       0.0     0.0    17.636431     0.779684    10.397529     5.094420
# ...

# %%
summary=df.describe().T
summary['median']=df.median()
summary['IQR']=df.quantile(0.75)-df.quantile(0.25)
print(summary)
# Out:
#            count        mean        std         min         25%         50%  \
# LB        2105.0  133.293227   9.979659  105.000000  126.000000  133.000000
# AC        2105.0    0.003143   0.003843   -0.008475    0.000000    0.001631
# FM        2105.0    0.001561   0.002473   -0.003831    0.000000    0.000000
# UC        2105.0    0.004358   0.003008   -0.005209    0.001838    0.004484
# DL        2105.0    0.001768   0.002672   -0.004934    0.000000    0.000000
# DS        2105.0    0.000000   0.000000    0.000000    0.000000    0.000000
# DP        2105.0    0.000000   0.000000    0.000000    0.000000    0.000000
# ASTV      2105.0   46.982677  17.636431  -11.500000   32.000000   49.000000
# MSTV      2105.0    1.302006   0.779684   -0.800000    0.700000    1.200000
# ALTV      2105.0    6.727067  10.397529  -16.500000    0.000000    0.000000
# MLTV      2105.0    8.022202   5.094420   -4.850000    4.600000    7.400000
# ...

# %%
#3
#---HISTPLOT
import matplotlib.pyplot as plt

# List of numerical columns to plot
numerical_columns = ['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV', 'MLTV']

# Create histograms for each numerical column
for column in numerical_columns:
    plt.figure(figsize=(10, 6))
    df[column].hist(bins=30)
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
#----BOXPLOT
import seaborn as sns

# Create boxplots for each numerical column
for column in numerical_columns:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.xlabel(column)
    plt.show()

# %%
#----PIECHART
plt.figure(figsize=(10, 6))
df['LB'].value_counts().plot(kind='pie', autopct='%1.1f%%') # LB should be a string
plt.title('Distribution of Tendency')
plt.ylabel('')
plt.show()

# %%
#---SCATTER PLOTS
# Example scatter plot between two numerical columns
plt.figure(figsize=(10, 6))
plt.scatter(df['LB'], df['MSTV'])
plt.title('Scatter Plot of LB vs MSTV')
plt.xlabel('LB (Baseline Fetal Heart Rate)')
plt.ylabel('MSTV (Mean Value of Short Term Variability)')
plt.show()

# %%
#----# correlation matrix
correlation_matrix = df.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
#---- pair plot for selected numerical columns
sns.pairplot(df[['LB', 'AC', 'FM', 'UC', 'DL', 'DS']])
plt.title('Pair Plot of Selected Variables')
plt.show()

# %%
#---violin plots

# %%
# Compute the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# Print correlations for interpretation
print(correlation_matrix)
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000 -0.080905 -0.006908 -0.163244 -0.156803 NaN NaN  0.286659
# AC       -0.080905  1.000000  0.077556  0.092891 -0.103652 NaN NaN -0.272180
# FM       -0.006908  0.077556  1.000000 -0.316271 -0.019206 NaN NaN  0.157023
# UC       -0.163244  0.092891 -0.316271  1.000000  0.270950 NaN NaN -0.216136
# DL       -0.156803 -0.103652 -0.019206  0.270950  1.000000 NaN NaN -0.113125
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.286659 -0.272180  0.157023 -0.216136 -0.113125 NaN NaN  1.000000
# MSTV     -0.297509  0.216044  0.069564  0.299116  0.566322 NaN NaN -0.435090
# ALTV      0.323341 -0.410445 -0.012706 -0.294475 -0.295480 NaN NaN  0.439183
# MLTV     -0.041988 -0.152315 -0.037086 -0.073800 -0.242513 NaN NaN -0.325637
# ...

# %%
#4
print(df.head())

# Example of plotting trends if a 'Date' column exists
if 'Date' in df.columns:
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)

    # Plot trends for numerical columns
    for column in df.columns:
        if df[column].dtype in ['float64', 'int64']:  # Only plot numerical columns
            plt.figure(figsize=(12, 6))
            df[column].plot()
            plt.title(f'Trend of {column} Over Time')
            plt.xlabel('Date')
            plt.ylabel(column)
            plt.show()
else:
    print("\n No DATE column found in the dataset.")
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  27.5
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#     MLTV  Width  Tendency  NSP
# 0   2.40   64.0  0.999926  1.0
# 1  10.40  130.0  0.000000  1.0
# 2  13.40  130.0  0.000000  1.0
# 3  20.35  117.0  1.000000  1.0
# 4  19.90  117.0  1.000000  1.0
#
#  No DATE column found in the dataset.

# %%
# - The correlation matrix shows strong positive correlations between 'ASTV' and 'MSTV',
#   which may indicate that as the percentage of abnormal short-term variability increases,
#   the mean value of short-term variability also increases.
# - A strong negative correlation between 'DL' (Late Decelerations) and 'AC' (Accelerations)
#   suggests that higher late decelerations are associated with fewer accelerations, potentially indicating fetal distress.
# - Trends over time reveal increasing trends in 'MSTV', suggesting that mean short-term variability is increasing over the observed period.
# - No temporal data is available
